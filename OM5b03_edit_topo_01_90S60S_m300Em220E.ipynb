# %% [markdown]
# # Sample 15arc-sec GEBCO_2023.nc on OM5 grid
#
# ## Apply edits to the topography.
#
# ## REGION= [[-90,-60,-300,-220,],]

# %%
# Notebook editor: Brandon.Reichl

# This notebook originated from Stephen Griffies, with many other contributors:
# Stephen.Griffies
# Alistair.Adcroft
# Robert.Hallberg
# Niki.Zadeh
# Raphael.Dussin

# %%
Region_Boundaries = [-90,-60,-300,-220]
Region_Name = '01: Southern Ocean 1'

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import numpy as np
import netCDF4
import xarray as xr
import cmocean
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

import sys
sys.path.insert(1, './tools/')
from topo_tools import *

# %%
# GEBCO-2020 + Bedmachine combined topography 

fname_gebco  = "/archive/gold/datasets/topography/GEBCO_2023/GEBCO_2023.nc"

GEBCO = GEBCO_data(fname_gebco)

plt.figure(figsize=(20,8))
plt.pcolormesh(GEBCO.lonq[::100], GEBCO.latq[::100], GEBCO.depth[::100,::100], cmap=cmocean.cm.deep)
plt.colorbar(); plt.title('GEBCO (subsampled)');
# Out:
# Resolution = 240 cells/degree
# GEBCO loaded with (nj,ni) =  (43200, 86400)  min(lon) =  -300.0  max(lon) =  60.0

# %%
OM4 = OM4_data('/archive/gold/datasets/OM4_025/mosaic.v20170622.unpacked/ocean_hgrid.nc',
               '/archive/gold/datasets/OM4_025/mosaic.v20170622.unpacked/ocean_static.nc',
               '/archive/gold/datasets/OM4_025/mosaic.v20170622.unpacked/ocean_mask.nc')
plt.figure(figsize=(20,8))
plt.pcolormesh(OM4.lonq, OM4.latq, OM4.depth, cmap=cmocean.cm.deep)
plt.colorbar(); plt.title('OM4 topography (after run-time edits)');

# %%
OM5 = OM5_data('/archive/jpk/OM5/OM5_025/prototypes/v20231109/tile_files/ocean_hgrid.nc',
               '/archive/jpk/OM5/OM5_025/prototypes/v20231109/tile_files/ocean_topog_merged.nc')

plt.figure(figsize=(20,8))
plt.pcolormesh(OM5.lonq, OM5.latq, OM5.depth, cmap=cmocean.cm.deep)
plt.colorbar(); plt.title('OM5 base topography (before edits)');
# Out:
# OM5 longitudes are inconsistent!
# OM5 latitudes are inconsistent!

# %%
# Broad view of region before edits 

broadview(OM4,OM5,
          (Region_Boundaries[2],Region_Boundaries[3]),
          (Region_Boundaries[0],Region_Boundaries[1]),
          0, 4000, Region_Name, om4=True, new=False)

# %%
region = Region(-295, -70, width_lon=10, width_lat=10)
map_region(region, 0, 4000, GEBCO, OM4, OM5, '', gebco_contours=[20],text_depths=False);
#No edits needed

region = Region(-295, -65, width_lon=10, width_lat=10)
map_region(region, 0, 4000, GEBCO, OM4, OM5, '', gebco_contours=[20],text_depths=False);
#No edits needed
# Out:
# Gebco (js:je,is:ie) = 3599:5999,0:2399
# OM4 model (js:je,is:ie) = 58:159,0:40
# OM5 model (js:je,is:ie) = 137:240,0:40
# Using xlim = (-300.0, -290.0) ylim = (-75.0, -65.0)
# Gebco (js:je,is:ie) = 4799:7199,0:2399
# OM4 model (js:je,is:ie) = 107:202,0:40
# OM5 model (js:je,is:ie) = 188:283,0:40
# Using xlim = (-300.0, -290.0) ylim = (-70.0, -60.0)

# %%
region = Region(-285, -70, width_lon=10, width_lat=10)
map_region(region, 0, 4000, GEBCO, OM4, OM5, '', gebco_contours=[20],text_depths=False);
#No edits needed.

region = Region(-285, -65, width_lon=10, width_lat=10)
map_region(region, 0, 4000, GEBCO, OM4, OM5, '', gebco_contours=[20],text_depths=False);
# No edits needed
# Out:
# Gebco (js:je,is:ie) = 3599:5999,2399:4800
# OM4 model (js:je,is:ie) = 58:159,38:80
# OM5 model (js:je,is:ie) = 137:240,38:80
# Using xlim = (-290.0, -280.0) ylim = (-75.0, -65.0)
# Gebco (js:je,is:ie) = 4799:7199,2399:4800
# OM4 model (js:je,is:ie) = 107:202,38:80
# OM5 model (js:je,is:ie) = 188:283,38:80
# Using xlim = (-290.0, -280.0) ylim = (-70.0, -60.0)

# %%
region = Region(-275, -70, width_lon=10, width_lat=10)
map_region(region, 0, 4000, GEBCO, OM4, OM5, '', gebco_contours=[20],text_depths=False);
#No edits needed

region = Region(-275, -65, width_lon=10, width_lat=10)
map_region(region, 0, 4000, GEBCO, OM4, OM5, '', gebco_contours=[20],text_depths=False);
#No edits needed
#Land removed
# Out:
# Gebco (js:je,is:ie) = 3599:5999,4800:7200
# OM4 model (js:je,is:ie) = 58:159,78:120
# OM5 model (js:je,is:ie) = 137:240,78:120
# Using xlim = (-280.0, -270.0) ylim = (-75.0, -65.0)
# Gebco (js:je,is:ie) = 4799:7199,4800:7200
# OM4 model (js:je,is:ie) = 107:202,78:120
# OM5 model (js:je,is:ie) = 188:283,78:120
# Using xlim = (-280.0, -270.0) ylim = (-70.0, -60.0)

# %%
region = Region(-265, -70, width_lon=10, width_lat=10)
map_region(region, 0, 4000, GEBCO, OM4, OM5, '', gebco_contours=[20],text_depths=False);
#No edits needed

region = Region(-265, -65, width_lon=10, width_lat=10)
map_region(region, 0, 4000, GEBCO, OM4, OM5, '', gebco_contours=[20],text_depths=False);
#No edits needed
# Out:
# Gebco (js:je,is:ie) = 3599:5999,7200:9600
# OM4 model (js:je,is:ie) = 58:159,118:160
# OM5 model (js:je,is:ie) = 137:240,118:160
# Using xlim = (-270.0, -260.0) ylim = (-75.0, -65.0)
# Gebco (js:je,is:ie) = 4799:7199,7200:9600
# OM4 model (js:je,is:ie) = 107:202,118:160
# OM5 model (js:je,is:ie) = 188:283,118:160
# Using xlim = (-270.0, -260.0) ylim = (-70.0, -60.0)

# %%
region = Region(-255, -70, width_lon=10, width_lat=10)
map_region(region, 0, 4000, GEBCO, OM4, OM5, '', gebco_contours=[20],text_depths=False);
#No edits needed

region = Region(-255, -65, width_lon=10, width_lat=10)
map_region(region, 0, 4000, GEBCO, OM4, OM5, '', gebco_contours=[20],text_depths=False);
#No edits needed
# Out:
# Gebco (js:je,is:ie) = 3599:5999,9600:12000
# OM4 model (js:je,is:ie) = 58:159,158:200
# OM5 model (js:je,is:ie) = 137:240,158:200
# Using xlim = (-260.0, -250.0) ylim = (-75.0, -65.0)
# Gebco (js:je,is:ie) = 4799:7199,9600:12000
# OM4 model (js:je,is:ie) = 107:202,158:200
# OM5 model (js:je,is:ie) = 188:283,158:200
# Using xlim = (-260.0, -250.0) ylim = (-70.0, -60.0)

# %%
region = Region(-245, -75, width_lon=10, width_lat=10)
map_region(region, 0, 4000, GEBCO, OM4, OM5, '', gebco_contours=[20],text_depths=False);
#No edits needed

region = Region(-245, -65, width_lon=10, width_lat=10)
map_region(region, 0, 4000, GEBCO, OM4, OM5, '', gebco_contours=[20],text_depths=False);
#No edits needed
# Out:
# Gebco (js:je,is:ie) = 2399:4799,12000:14400
# OM4 model (js:je,is:ie) = 0:109,199:240
# OM5 model (js:je,is:ie) = 86:190,198:240
# Using xlim = (-250.0, -240.0) ylim = (-80.0, -70.0)
# /net2/ovs/miniconda3/envs/mom6gridCV2/lib/python3.9/site-packages/matplotlib/contour.py:1430: UserWarning: Warning: converting a masked element to nan.
#   self.zmax = float(z.max())
# /net2/ovs/miniconda3/envs/mom6gridCV2/lib/python3.9/site-packages/matplotlib/contour.py:1431: UserWarning: Warning: converting a masked element to nan.
#   self.zmin = float(z.min())
# /home/Olga.Sergienko/om5_topo_edits/./tools/topo_tools.py:194: UserWarning: No contour levels were found within the data range.
#   thisax.contour(GEBCO.lonh[Gis:Gie], GEBCO.lath[Gjs:Gje], zmask( GEBCO.depth[Gjs:Gje,Gis:Gie] ),
# Gebco (js:je,is:ie) = 4799:7199,12000:14400
# OM4 model (js:je,is:ie) = 107:202,198:240
# OM5 model (js:je,is:ie) = 188:283,198:240
# Using xlim = (-250.0, -240.0) ylim = (-70.0, -60.0)

# %%
region = Region(-235, -70, width_lon=10, width_lat=10)
map_region(region, 0, 4000, GEBCO, OM4, OM5, '', gebco_contours=[20],text_depths=False);
#No edits needed

region = Region(-235, -65, width_lon=10, width_lat=10)
map_region(region, 0, 4000, GEBCO, OM4, OM5, '', gebco_contours=[20],text_depths=False);
#No edits needed
# Out:
# Gebco (js:je,is:ie) = 3599:5999,14400:16800
# OM4 model (js:je,is:ie) = 58:159,238:280
# OM5 model (js:je,is:ie) = 137:240,238:280
# Using xlim = (-240.0, -230.0) ylim = (-75.0, -65.0)
# Gebco (js:je,is:ie) = 4799:7199,14400:16800
# OM4 model (js:je,is:ie) = 107:202,238:280
# OM5 model (js:je,is:ie) = 188:283,238:280
# Using xlim = (-240.0, -230.0) ylim = (-70.0, -60.0)

# %%
region = Region(-225, -70, width_lon=10, width_lat=10)
map_region(region, 0, 4000, GEBCO, OM4, OM5, '', gebco_contours=[20],text_depths=False);
#No edits needed

region = Region(-225, -65, width_lon=10, width_lat=10)
map_region(region, 0, 4000, GEBCO, OM4, OM5, '', gebco_contours=[20],text_depths=False);
#No edits needed
# Out:
# Gebco (js:je,is:ie) = 3599:5999,16800:19200
# OM4 model (js:je,is:ie) = 58:159,278:320
# OM5 model (js:je,is:ie) = 137:240,278:320
# Using xlim = (-230.0, -220.0) ylim = (-75.0, -65.0)
# Gebco (js:je,is:ie) = 4799:7199,16800:19200
# OM4 model (js:je,is:ie) = 107:202,278:320
# OM5 model (js:je,is:ie) = 188:283,278:320
# Using xlim = (-230.0, -220.0) ylim = (-70.0, -60.0)

# %%
OM5.write_nc("om5_topo_edits_region_01b.nc")
